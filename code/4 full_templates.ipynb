# %%
import pandas as pd

# %%
filename = '../data/3_name_groups.csv'
names = pd.read_csv(filename, on_bad_lines='warn')

# %%
filename = '../data/full_descriptors.csv'
descriptors = pd.read_csv(filename, on_bad_lines='warn')

# %%
descriptors
# Out:
#                 partial_1              partial_2             partial_3  \
# 0          am a stutterer        was a stutterer        is a stutterer
# 1    am a wheelchair user  was a wheelchair user  is a wheelchair user
# 2           am an amputee         was an amputee         is an amputee
# 3                 am Deaf               was Deaf               is Deaf
# 4      am hard-of-hearing    was hard-of-hearing    is hard-of-hearing
# ..                    ...                    ...                   ...
# 725   am socially awkward   was socially awkward   is socially awkward
# 726              am cruel              was cruel              is cruel
# 727          am ambitious          was ambitious          is ambitious
# 728          am nurturing          was nurturing          is nurturing
# 729             am loving             was loving             is loving
#
#             descriptor       dataset     axis    bucket group
# 0          a stutterer  HolisticBias  ability    (none)   NaN
# 1    a wheelchair user  HolisticBias  ability    (none)   NaN
# 2           an amputee  HolisticBias  ability    (none)   NaN
# 3                 Deaf  HolisticBias  ability  auditory   NaN
# 4      hard-of-hearing  HolisticBias  ability  auditory   NaN
# ..                 ...           ...      ...       ...   ...
# 725   socially awkward     StereoSet      NaN       NaN   NaN
# 726              cruel     StereoSet      NaN       NaN   NaN
# 727          ambitious     StereoSet      NaN       NaN   NaN
# 728          nurturing     StereoSet      NaN       NaN   NaN
# 729             loving     StereoSet      NaN       NaN   NaN
#
# [730 rows x 8 columns]

# %%
names = names.drop('Unnamed: 0', axis=1)

names.head()
# Out:
#        firstname  Cluster Ethnicity  Ethnicity Probability Gender  \
# 0  Abdourahamane      105   AFRICAN                 65.905      M
# 1        Adebayo       43   AFRICAN                 93.061      M
# 2          Chuka       43   AFRICAN                 46.488      M
# 3         Abdoul      105   AFRICAN                 59.780      M
# 4      Mohamadou      105   AFRICAN                 86.458      M
#
#               Group
# 0  ('AFRICAN', 'M')
# 1  ('AFRICAN', 'M')
# 2  ('AFRICAN', 'M')
# 3  ('AFRICAN', 'M')
# 4  ('AFRICAN', 'M')

# %%
len(names['Ethnicity'].unique())
# Out:
# 20

# %%
names['_merge_key'] = 1
descriptors['_merge_key'] = 1

template_df = pd.merge(names, descriptors, on='_merge_key')

template_df = template_df.drop(columns=['_merge_key'])

template_df.tail()
# Out:
#        firstname  Cluster Ethnicity  Ethnicity Probability Gender  \
# 291995      Nate       13   ENGLISH                 97.417      M
# 291996      Nate       13   ENGLISH                 97.417      M
# 291997      Nate       13   ENGLISH                 97.417      M
# 291998      Nate       13   ENGLISH                 97.417      M
# 291999      Nate       13   ENGLISH                 97.417      M
#
#                    Group            partial_1             partial_2  \
# 291995  ('ENGLISH', 'M')  am socially awkward  was socially awkward
# 291996  ('ENGLISH', 'M')             am cruel             was cruel
# 291997  ('ENGLISH', 'M')         am ambitious         was ambitious
# 291998  ('ENGLISH', 'M')         am nurturing         was nurturing
# 291999  ('ENGLISH', 'M')            am loving            was loving
#
#                   partial_3        descriptor    dataset axis bucket group
# 291995  is socially awkward  socially awkward  StereoSet  NaN    NaN   NaN
# 291996             is cruel             cruel  StereoSet  NaN    NaN   NaN
# 291997         is ambitious         ambitious  StereoSet  NaN    NaN   NaN
# 291998         is nurturing         nurturing  StereoSet  NaN    NaN   NaN
# 291999            is loving            loving  StereoSet  NaN    NaN   NaN

# %%
descriptors['axis'].unique()
# Out:
# array(['ability', 'age', 'body_type', 'characteristics', 'cultural',
#        'gender_and_sex', 'nonce', 'political_ideologies',
#        'race_ethnicity', 'religion', 'sexual_orientation',
#        'socioeconomic_class', nan], dtype=object)

# %%
def create_template(row, template_number = 1):
    if template_number == 1:
        template = "My name is {name}, I {descriptor}."
        return template.format(name=row['firstname'], descriptor=row['partial_1'])

    elif template_number == 2:
        template = "{name} {descriptor}."
        return template.format(name=row['firstname'], descriptor=row['partial_2'])

    elif template_number == 3:
        template = "{name} {descriptor}."
        return template.format(name=row['firstname'], descriptor=row['partial_3'])


template_df['template_1'] = template_df.apply(lambda row: create_template(row, 1), axis=1)
template_df['template_2'] = template_df.apply(lambda row: create_template(row, 2), axis=1)
template_df['template_3'] = template_df.apply(lambda row: create_template(row, 3), axis=1)

# %%
def create_input(row, template_number = 1):
    if template_number == 1:
        template = "My name is {name}, I "
        return template.format(name=row['firstname'])

template_df['input_1'] = template_df.apply(lambda row: create_input(row, 1), axis=1)

# %%
print(len(template_df))
template_df.tail()
# Out:
# 292000
#        firstname  Cluster Ethnicity  Ethnicity Probability Gender  \
# 291995      Nate       13   ENGLISH                 97.417      M
# 291996      Nate       13   ENGLISH                 97.417      M
# 291997      Nate       13   ENGLISH                 97.417      M
# 291998      Nate       13   ENGLISH                 97.417      M
# 291999      Nate       13   ENGLISH                 97.417      M
#
#                    Group            partial_1             partial_2  \
# 291995  ('ENGLISH', 'M')  am socially awkward  was socially awkward
# 291996  ('ENGLISH', 'M')             am cruel             was cruel
# 291997  ('ENGLISH', 'M')         am ambitious         was ambitious
# 291998  ('ENGLISH', 'M')         am nurturing         was nurturing
# 291999  ('ENGLISH', 'M')            am loving            was loving
#
#                   partial_3        descriptor    dataset axis bucket group  \
# 291995  is socially awkward  socially awkward  StereoSet  NaN    NaN   NaN
# 291996             is cruel             cruel  StereoSet  NaN    NaN   NaN
# 291997         is ambitious         ambitious  StereoSet  NaN    NaN   NaN
# 291998         is nurturing         nurturing  StereoSet  NaN    NaN   NaN
# 291999            is loving            loving  StereoSet  NaN    NaN   NaN
#
#                                      template_1                  template_2  \
# 291995  My name is Nate, I am socially awkward.  Nate was socially awkward.
# 291996             My name is Nate, I am cruel.             Nate was cruel.
# 291997         My name is Nate, I am ambitious.         Nate was ambitious.
# 291998         My name is Nate, I am nurturing.         Nate was nurturing.
# 291999            My name is Nate, I am loving.            Nate was loving.
#
#                        template_3              input_1
# 291995  Nate is socially awkward.  My name is Nate, I
# 291996             Nate is cruel.  My name is Nate, I
# 291997         Nate is ambitious.  My name is Nate, I
# 291998         Nate is nurturing.  My name is Nate, I
# 291999            Nate is loving.  My name is Nate, I

# %%
template_df.to_csv('../data/4a_full_templates.csv')

# %%
## Output Ghavami Peplau templates separately for validation experiment

gp_df = template_df[template_df["dataset"] == "GhavamiPeplau"]

print(len(gp_df))
gp_df.to_csv("../data/4b_gp_templates.csv")
# Out:
# 20400
